# %%
import numpy as np

# %%
brigadas = np.array([[['Juan', 'Alex', 'Antonio'], ['Arturo', 'Valentina', 'Vanessa']],
                     [['Ricardo', 'Felipe', 'Paola'], ['Marco', 'Jorge', 'Alejandro']],
                     [['Esteban', 'Ramiro', 'Antonio'], ['Sara', 'Camila', 'Emily']],
                     [['Arley', 'Andrea', 'Alejandra'], ['Maria', 'Angel', 'Jesus']],
                     [['Emmanuel', 'Nelson', 'Fabian'], ['Sarai', 'Camilo', 'Emely']]])
print(brigadas)
# Out:
# [[['Juan' 'Alex' 'Antonio']
#   ['Arturo' 'Valentina' 'Vanessa']]
#
#  [['Ricardo' 'Felipe' 'Paola']
#   ['Marco' 'Jorge' 'Alejandro']]
#
#  [['Esteban' 'Ramiro' 'Antonio']
#   ['Sara' 'Camila' 'Emily']]
#
#  [['Arley' 'Andrea' 'Alejandra']
#   ['Maria' 'Angel' 'Jesus']]
#
#  [['Emmanuel' 'Nelson' 'Fabian']
#   ['Sarai' 'Camilo' 'Emely']]]

# %%
brigadas.ndim
# Out:
# 3

# %%
brigadas.shape
# Out:
# (5, 2, 3)

# %%
brigadas[1:3,:,:]
# Out:
# array([[['Ricardo', 'Felipe', 'Paola'],
#         ['Marco', 'Jorge', 'Alejandro']],
#
#        [['Esteban', 'Ramiro', 'Antonio'],
#         ['Sara', 'Camila', 'Emily']]], dtype='<U9')

# %%
brigadas[:, 1, 0:2]
# Out:
# array([['Arturo', 'Valentina'],
#        ['Marco', 'Jorge'],
#        ['Sara', 'Camila'],
#        ['Maria', 'Angel'],
#        ['Sarai', 'Camilo']], dtype='<U9')

# %%
brigadas[:, 1, 0:2]
# Out:
# array([['Arturo', 'Valentina'],
#        ['Marco', 'Jorge'],
#        ['Sara', 'Camila'],
#        ['Maria', 'Angel'],
#        ['Sarai', 'Camilo']], dtype='<U9')

# %%
type(brigadas[:, 1, 0:2])
# Out:
# numpy.ndarray

# %%
sustitutos = np.array([['John', 'Ringo', 'Paul'],
                       ['Keith', 'Mick', 'Charlie']])

# %%
sustitutos.shape
# Out:
# (2, 3)

# %%
brigadas[4,:,:] = 'sustitutos'

# %%
brigadas[1,1,:] = ['parcifal', 'Gawain', 'Lancelot']

# %%
brigadas[4,1,2] = 'Pascual'

# %%
matriz_1 = np.array([[1,2,3], [4,0,-5], [-6,-7,-8]])

# %%
matriz_1 + 100
# Out:
# array([[101, 102, 103],
#        [104, 100,  95],
#        [ 94,  93,  92]])

# %%
matriz_1[2,:] *3
# Out:
# array([-18, -21, -24])

# %%
3 / matriz_1
# Out:
# /tmp/ipykernel_7671/113740686.py:1: RuntimeWarning: divide by zero encountered in divide
#   3 / matriz_1
# array([[ 3.        ,  1.5       ,  1.        ],
#        [ 0.75      ,         inf, -0.6       ],
#        [-0.5       , -0.42857143, -0.375     ]])

# %%
matriz_1 / 2
# Out:
# array([[ 0.5,  1. ,  1.5],
#        [ 2. ,  0. , -2.5],
#        [-3. , -3.5, -4. ]])

# %%
matriz_1 > 1
# Out:
# array([[False,  True,  True],
#        [ True, False, False],
#        [False, False, False]])

# %%
matriz_1 < 1
# Out:
# array([[False, False, False],
#        [False,  True,  True],
#        [ True,  True,  True]])

# %%
matriz_1.shape
# Out:
# (3, 3)

# %%
matriz_2 = np.array([1,2,3])

# %%
matriz_2.shape
# Out:
# (3,)

# %%
matriz_1 * matriz_2
# Out:
# array([[  1,   4,   9],
#        [  4,   0, -15],
#        [ -6, -14, -24]])

# %%
matriz_3 = np.array([[2], [4], [6]])

# %%
matriz_3
# Out:
# array([[2],
#        [4],
#        [6]])

# %%
matriz_3.shape
# Out:
# (3, 1)

# %%
matriz_3 * matriz_1
# Out:
# array([[  2,   4,   6],
#        [ 16,   0, -20],
#        [-36, -42, -48]])

# %%
m1 = np.array

# %% [markdown]
# Esto no es lo mismo con las operaciones de algebra lineal
